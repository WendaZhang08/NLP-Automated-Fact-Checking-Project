# %%
# !python colab_script.py
# Out:
# Python version: 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]
# Command succeeded: pip --version
# pip 23.3.1 from E:\Software\Anaconda\envs\tf-gpu\lib\site-packages\pip (python 3.8)
#
#
# Command succeeded: pip show papermill || pip install papermill
# Name: papermill
# Version: 2.6.0
# Summary: Parameterize and run Jupyter and nteract Notebooks
# Home-page: https://github.com/nteract/papermill
# Author: nteract contributors
# Author-email: nteract@googlegroups.com
# License: BSD
# Location: e:\software\anaconda\envs\tf-gpu\lib\site-packages
# Requires: ansicolors, click, entrypoints, nbclient, nbformat, pyyaml, requests, tenacity, tqdm
# Required-by:
#
# Command succeeded: pip install numpy nltk scikit-learn keras tensorflow
# Requirement already satisfied: numpy in e:\software\anaconda\envs\tf-gpu\lib\site-packages (1.18.5)
# Requirement already satisfied: nltk in e:\software\anaconda\envs\tf-gpu\lib\site-packages (3.8.1)
# Requirement already satisfied: scikit-learn in e:\software\anaconda\envs\tf-gpu\lib\site-packages (1.2.2)
# Requirement already satisfied: keras in e:\software\anaconda\envs\tf-gpu\lib\site-packages (2.4.3)
# Requirement already satisfied: tensorflow in e:\software\anaconda\envs\tf-gpu\lib\site-packages (2.3.0)
# Requirement already satisfied: click in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: scipy>=1.3.2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: pyyaml in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from keras) (6.0.1)
# Requirement already satisfied: h5py in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast==0.3.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: wheel>=0.26 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (0.43.0)
# Requirement already satisfied: six>=1.12.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio>=1.8.6 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (68.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.3.8)
# Requirement already satisfied: colorama in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.3.0->tensorflow) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.17.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.2.2)
#
# Command succeeded: papermill GroupID__COMP90042_Project_2024.ipynb outputs/project_output.ipynb
#
# Command succeeded: python eval.py --predictions data/dev_predict.json --groundtruth data/dev-claims.json
# Evidence Retrieval F-score (F)    = 0.07781900639043496
# Claim Classification Accuracy (A) = 0.474025974025974
# Harmonic Mean of F and A          = 0.13369055300321644
#
# Evaluation result:
# Evidence Retrieval F-score (F)    = 0.07781900639043496
# Claim Classification Accuracy (A) = 0.474025974025974
# Harmonic Mean of F and A          = 0.13369055300321644
#
# Script finished!

# %%
from IPython import get_ipython

# Check if running on Google Colab
if 'google.colab' in str(get_ipython()):
    print("Running on Google Colab")
    # !python colab_script.py
else:
    print("Not running on Google Colab")
# Out:
# Python version: 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]
# Command succeeded: pip --version
# pip 23.3.1 from E:\Software\Anaconda\envs\tf-gpu\lib\site-packages\pip (python 3.8)
#
#
# Command succeeded: pip show papermill || pip install papermill
# Name: papermill
# Version: 2.6.0
# Summary: Parameterize and run Jupyter and nteract Notebooks
# Home-page: https://github.com/nteract/papermill
# Author: nteract contributors
# Author-email: nteract@googlegroups.com
# License: BSD
# Location: e:\software\anaconda\envs\tf-gpu\lib\site-packages
# Requires: ansicolors, click, entrypoints, nbclient, nbformat, pyyaml, requests, tenacity, tqdm
# Required-by:
#
# Command succeeded: pip install numpy nltk scikit-learn keras tensorflow
# Requirement already satisfied: numpy in e:\software\anaconda\envs\tf-gpu\lib\site-packages (1.18.5)
# Requirement already satisfied: nltk in e:\software\anaconda\envs\tf-gpu\lib\site-packages (3.8.1)
# Requirement already satisfied: scikit-learn in e:\software\anaconda\envs\tf-gpu\lib\site-packages (1.2.2)
# Requirement already satisfied: keras in e:\software\anaconda\envs\tf-gpu\lib\site-packages (2.4.3)
# Requirement already satisfied: tensorflow in e:\software\anaconda\envs\tf-gpu\lib\site-packages (2.3.0)
# Requirement already satisfied: click in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: scipy>=1.3.2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: pyyaml in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from keras) (6.0.1)
# Requirement already satisfied: h5py in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast==0.3.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: wheel>=0.26 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (0.43.0)
# Requirement already satisfied: six>=1.12.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio>=1.8.6 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (68.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.3.8)
# Requirement already satisfied: colorama in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.3.0->tensorflow) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.17.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\software\anaconda\envs\tf-gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.2.2)
#
# Command succeeded: papermill GroupID__COMP90042_Project_2024.ipynb project_output.ipynb
#
# Command succeeded: python eval.py --predictions data/dev_predict.json --groundtruth data/dev-claims.json
# Evidence Retrieval F-score (F)    = 0.07781900639043496
# Claim Classification Accuracy (A) = 0.474025974025974
# Harmonic Mean of F and A          = 0.13369055300321644
#
# Evaluation result:
# Evidence Retrieval F-score (F)    = 0.07781900639043496
# Claim Classification Accuracy (A) = 0.474025974025974
# Harmonic Mean of F and A          = 0.13369055300321644
#
# File Testing_Evaluation_Result.txt already exists. Skipping write operation.
